# %% [markdown]
# # EMS Co-Pilot
#
# Reproducible energy analytics and optional PDF-grounded AI reports for a steel-plant dataset.
#
# **Start here:** open this notebook from the repository root after following [SETUP.md](docs/SETUP.md). Run all cells for an offline walkthrough. Optional API calls, Word exports and the local dashboard are disabled until you deliberately enable their switches.
#
# The source database contains six identical copies of each interval. The analytics layer removes exact duplicates in memory, rejects conflicting readings and leaves the database unchanged. Dataset CO2 is not a verified Scope 1/2/3 inventory. See [DATA.md](docs/DATA.md).

# %%
from pathlib import Path
from ems_copilot import EnergyDataset, render_markdown

DB_PATH = Path("ems.db")
START_DATE = "2018-01-01"
END_DATE = "2018-01-07"
RUN_AI = False
SAVE_REPORT = False
EXPORT_DOCX = False
LAUNCH_UI = False

dataset = EnergyDataset(DB_PATH)
dataset.audit()

# %% [markdown]
# ## Inspect the evidence
#
# Dates are inclusive calendar dates. Midnight belongs to the date printed in the source timestamp; the workflow does not silently shift interval boundaries. Missing observations are disclosed, not filled with zero.

# %%
snapshot = dataset.snapshot(START_DATE, END_DATE, top_n=5)
snapshot["kpis"], snapshot["data_quality"]

# %%
from IPython.display import Markdown, display

report_text = render_markdown(snapshot)
display(Markdown(report_text))

# %% [markdown]
# ## Save a local report
#
# Set `SAVE_REPORT = True` above to create a new Markdown file in `reports/`. Existing files are never overwritten; choose a new filename for another export. No report is emailed.

# %%
if SAVE_REPORT:
    report_path = Path("reports") / f"energy_{START_DATE}_{END_DATE}.md"
    report_path.parent.mkdir(parents=True, exist_ok=True)
    with report_path.open("x", encoding="utf-8") as output:
        output.write(report_text)
    print(f"Saved {report_path}")

# %% [markdown]
# ## Optional: grounded AI draft
#
# Install the `ai` extra and set `OPENAI_API_KEY` securely in the environment before launching Jupyter. Set `RUN_AI = True` only when ready to send the PDF chunks, your question and summary analytics to OpenAI. API usage may incur charges. The first run indexes the PDF; later runs resume the same corpus/model collection.
#
# The optional provider connection has mock-based tests; a live response is not required for the offline walkthrough. Review all AI claims and the returned page references before use. See [USAGE.md](docs/USAGE.md).

# %%
if RUN_AI:
    from ems_copilot.assistant import index_knowledge, answer_question

    knowledge = index_knowledge("GHG_Protocol-revised.pdf")
    ai_result = answer_question(
        "Which energy investigations should we prioritize, given the observed evidence and its limitations?",
        snapshot, knowledge, top_k=3,
    )
    display(Markdown(ai_result["answer"]))
    for source in ai_result["sources"]:
        print(f"{source['source']}, page {source['page']}")

# %% [markdown]
# ## Optional: Word export or local dashboard
#
# Word export requires the `ai` extra. The dashboard requires the `ui` extra and binds to this machine only. Neither option starts automatically. The dashboard displays deterministic reports; use the previous cell for AI drafts.

# %%
if EXPORT_DOCX:
    from ems_copilot.assistant import save_docx
    text_to_export = report_text
    if RUN_AI:
        text_to_export += "\n\n# AI draft — review required\n\n" + ai_result["answer"]
    print(save_docx(text_to_export, Path("reports") / f"energy_{START_DATE}_{END_DATE}.docx"))

if LAUNCH_UI:
    from app import build_app
    app = build_app(dataset)
    app.launch(server_name="127.0.0.1", share=False)
